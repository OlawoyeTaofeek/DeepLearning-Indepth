# %%
from schema import ChatOpenAI, PromptTemplate

# %%
prompt = PromptTemplate.from_template("Explain {topic} in simple terms. using {language} language.")
print(prompt)
print(prompt.input_variables)

msgs = prompt.format(topic="AI", language="English")
print(msgs)
# Out:
# input_variables=['topic', 'language'] input_types={} partial_variables={} template='Explain {topic} in simple terms. using {language} language.'
# ['topic', 'language']
# Explain AI in simple terms. using English language.

# %%
prompt
# Out:
# PromptTemplate(input_variables=['topic', 'language'], input_types={}, partial_variables={}, template='Explain {topic} in simple terms. using {language} language.')

# %%
from langchain_mimic import PromptTemplate
